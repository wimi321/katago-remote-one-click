# %% [markdown]
# # KataGo Remote One-Click / KataGo 远程算力一键部署
#
# 1. In Colab, choose **Runtime > Change runtime type > T4 GPU**.
# 2. Run the cell below and wait for the WSS link and QR code.
# 3. Paste the link into **LizzieYzy Next > Remote Compute > Custom Compute**.
#
# 请先选择 **运行时 > 更改运行时类型 > T4 GPU**，再运行下方单元格。看到链接和二维码后，将链接粘贴到 **LizzieYzy Next > 远程算力 > 自建算力**。

# %%
# !curl -fsSL https://raw.githubusercontent.com/wimi321/katago-remote-one-click/v0.1.0/install.sh | bash

# %% [markdown]
# ## Show the link again / 再次显示链接
# Run this cell if the first output was cleared. / 如果上方输出被清除，运行这一格。

# %%
!~/.local/bin/katago-remote show

# %% [markdown]
# The Colab link is temporary and stops when the runtime disconnects. Never share the private WSS link.
#
# Colab 链接是临时的，运行时断开后便会失效。请勿分享私密 WSS 链接。
